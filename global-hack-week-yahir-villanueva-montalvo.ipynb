# %% [markdown]
# <a href="https://www.kaggle.com/code/yahirvillanueva/global-hack-week-yahir-villanueva-montalvo?scriptVersionId=158357885" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Challenge #1
#
#
# This Challenge is Called "Hello, World!". We have to type out code to print Hello, World!

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# # Challenge #2
#
# This Challege is to Make sorting method to make a equation/list of work
